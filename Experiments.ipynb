# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

sns.set()
#sns.set(rc={'figure.figsize':(10,6.5)})
sns.set_context("notebook", font_scale=1.5)
sns.set_style('white')
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('png')

# %%
## visualise series of values from JSON
# pd.read_json('xxx.json').plot()

# %% [markdown]
# Writes before adding index
# ======================

# %%
before_opt_writes = pd.read_json('before_opt_write.json')
before_opt_writes.plot()
before_opt_writes.plot.hist()
print('Mean before:', before_opt_writes.mean()[0])
# Out:
# Mean before: 0.059005286719838

# %% [markdown]
# Writes after adding index
# ====================

# %%
after_opt_writes = pd.read_json('after_opt_write.json')
after_opt_writes.plot()
after_opt_writes.plot.hist()

print('Mean after opt:', after_opt_writes.mean()[0])
# Out:
# Mean after opt: 0.05889456842980639

# %% [markdown]
# Reads before adding index
# =========================

# %%
before_opt_read = pd.read_json('before_opt_read.json')
before_opt_read.plot()
before_opt_read.plot.hist()
print('Mean before opt:', before_opt_read.mean()[0])
# Out:
# Mean before opt: 0.0026588098328169975

# %% [markdown]
# Reads after adding index
# ====================

# %%
after_opt_read = pd.read_json('after_opt_read.json')
after_opt_read.plot()
after_opt_read.plot.hist()

print('Mean after opt:', after_opt_read.mean()[0])
# Out:
# Mean after opt: 0.0008285661861964865
